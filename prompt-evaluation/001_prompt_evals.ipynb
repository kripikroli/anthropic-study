# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merge the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    score = 10

    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(data_set):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS Account ID Extractor from ARN\n\n```python\nimport re\nfrom typing import Optional\n\ndef extract_account_id_from_arn(arn: str) -> Optional[str]:\n    \"\"\"\n    Extracts the AWS account ID from an ARN string.\n    \n    ARN format: arn:partition:service:region:account-id:resource-type/resource-id\n    \n    Args:\n        arn: AWS ARN string\n        \n    Returns:\n        The 12-digit account ID if present, None otherwise\n        \n    Examples:\n        >>> extract_account_id_from_arn('arn:aws:iam::123456789012:user/Development/product_1234/*')\n        '123456789012'\n        \n        >>> extract_account_id_from_arn('arn:aws:s3:::my-bucket/my-key')\n        None\n        \n        >>> extract_account_id_from_arn('arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0')\n        '123456789012'\n    \"\"\"\n    \n    if not isinstance(arn, str) or not arn.strip():\n        return None\n    \n    try:\n        # ARN format: arn:partition:service:region:account-id:resource\n        # Split by colon\n        parts = arn.split(':')\n        \n        # Valid ARN should have at least 6 parts\n        if len(parts) < 6:\n            return None\n        \n        # Account ID is at index 4 (0-indexed)\n        account_id = parts[4]\n        \n        # Account ID should be either:\n        # - Empty string (for services that don't use account IDs like S3)\n        # - 12 digits (for services that use account IDs)\n        if account_id == '':\n            return None\n        \n        # Validate that account ID is exactly 12 digits\n        if re.match(r'^\\d{12}$', account_id):\n            return account_id\n        else:\n            return None\n            \n    except (IndexError, AttributeError):\n        return None\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # (input, expected_output)\n        ('arn:aws:s3:::my-bucket/my-key', None),\n        ('arn:aws:iam::123456789012:user/Development/product_1234/*', '123456789012'),\n        ('arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0', '123456789012'),\n        ('arn:aws:lambda:us-west-2:123456789012:function:my-function', '123456789012'),\n        ('arn:aws:s3:::bucket-name', None),\n        ('arn:aws:dynamodb:us-east-1:123456789012:table/MyTable', '123456789012'),\n        ('arn:aws:rds:us-east-1:123456789012:db:mydbinstance', '123456789012'),\n        ('arn:aws:sns:us-east-1:123456789012:my-topic', '123456789012'),\n        ('arn:aws:sqs:us-east-1:123456789012:myqueue', '123456789012'),\n        ('invalid-arn', None),\n        ('', None),\n        ('arn:aws:iam::999999999999:role/MyRole', '999999999999'),\n        ('arn:aws:iam::12345:role/MyRole', None),  # Invalid account ID (too short)\n    ]\n    \n    print(\"Testing extract_account_id_from_arn():\\n\")\n    all_passed = True\n    \n    for arn, expected in test_cases:\n        result = extract_account_id_from_arn(arn)\n        passed = result == expected\n        all_passed = all_passed and passed\n        \n        status = \"\u2713 PASS\" if passed else \"",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS account ID from an ARN string. For example, given 'arn:aws:s3:::my-bucket/my-key', it should return the account ID if present, or None if not applicable."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Policy for Read-Only S3 Access\n\nHere's a JSON IAM policy that grants read-only access to the specified S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ReadOnlyAccessToMyDataBucket\",\n      \"Effect\": \"Allow\",\n      \"Principal\": {\n        \"AWS\": \"arn:aws:iam::123456789012:user/john\"\n      },\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Sid\": \"ListBucketContents\",\n      \"Effect\": \"Allow\",\n      \"Principal\": {\n        \"AWS\": \"arn:aws:iam::123456789012:user/john\"\n      },\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Policy Explanation\n\n| Component | Details |\n|-----------|---------|\n| **Version** | 2012-10-17 (latest IAM policy version) |\n| **Principal** | John's user ARN in account 123456789012 |\n| **Actions** | Limited to read operations only |\n\n### Allowed Actions:\n- **s3:GetObject** - Read objects from the bucket\n- **s3:GetObjectVersion** - Access previous object versions\n- **s3:ListBucket** - List bucket contents\n- **s3:GetBucketVersioning** - Check bucket versioning status\n\nThis policy follows the **principle of least privilege** by granting only the minimum permissions needed for read-only access.",
#     "test_case": {
#       "task": "Create a JSON object representing an AWS IAM policy that grants read-only access to a specific S3 bucket named 'my-data-bucket' for the principal 'arn:aws:iam::123456789012:user/john'."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n- `^` - Start of string anchor\n- `i-` - Literal prefix that all EC2 instance IDs begin with\n- `[0-9a-f]{17}` - Exactly 17 hexadecimal characters (0-9 and a-f)\n- `$` - End of string anchor\n\n## Examples\n\n```python\nimport re\n\npattern = r'^i-[0-9a-f]{17}$'\n\n# Valid matches\nprint(re.match(pattern, 'i-0a1b2c3d4e5f6g7h8'))  # False (g and h are not hex)\nprint(re.match(pattern, 'i-0a1b2c3d4e5f6a7b8'))  # True\nprint(re.match(pattern, 'i-1234567890abcdef0'))  # True\n\n# Invalid matches\nprint(re.match(pattern, 'i-0a1b2c3d4e5f6g7h'))   # False (16 chars, not 17)\nprint(re.match(pattern, 'i-0a1b2c3d4e5f6a7b8c')) # False (18 chars)\nprint(re.match(pattern, '0a1b2c3d4e5f6a7b8'))    # False (missing 'i-')\n```\n\n## Case-Insensitive Variant\n\nIf you need to match uppercase hexadecimal characters as well:\n\n```regex\n^i-[0-9a-fA-F]{17}$\n```\n\nOr using the case-insensitive flag:\n\n```python\nre.match(r'^i-[0-9a-f]{17}$', instance_id, re.IGNORECASE)\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs. EC2 instance IDs follow the format 'i-' followed by exactly 17 hexadecimal characters (example: i-0a1b2c3d4e5f6g7h8)."
#     },
#     "score": 10
#   }
# ]
